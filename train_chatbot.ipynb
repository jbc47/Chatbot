# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.optimizers import SGD
import random
# Out:
# [nltk_data] Downloading package punkt to C:\Users\John
# [nltk_data]     Barry\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\John
# [nltk_data]     Barry\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\wordnet.zip.

# %%
words=[]
classes = []
documents = []
ignore_words = ['?', '!']
data_file = open('intents.json').read()
intents = json.loads(data_file)

# %%
for intent in intents['intents']:
    for pattern in intent['patterns']:
        #tokenize each word
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        #add documents in the corpus
        documents.append((w, intent['tag']))
        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# %%
# lemmatize, lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))
# sort classes
classes = sorted(list(set(classes)))
# documents = combination between patterns and intents
print (len(documents), "documents")
# classes = intents
print (len(classes), "classes", classes)
# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)
pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))
# Out:
# 47 documents
# 9 classes ['adverse_drug', 'blood_pressure', 'blood_pressure_search', 'goodbye', 'greeting', 'hospital_search', 'options', 'pharmacy_search', 'thanks']
# 88 unique lemmatized words ["'s", ',', 'a', 'adverse', 'all', 'anyone', 'are', 'awesome', 'be', 'behavior', 'blood', 'by', 'bye', 'can', 'causing', 'chatting', 'check', 'could', 'data', 'day', 'detail', 'do', 'dont', 'drug', 'entry', 'find', 'for', 'give', 'good', 'goodbye', 'have', 'hello', 'help', 'helpful', 'helping', 'hey', 'hi', 'history', 'hola', 'hospital', 'how', 'i', 'id', 'is', 'later', 'list', 'load', 'locate', 'log', 'looking', 'lookup', 'management', 'me', 'module', 'nearby', 'next', 'nice', 'of', 'offered', 'open', 'patient', 'pharmacy', 'pressure', 'provide', 'reaction', 'related', 'result', 'search', 'searching', 'see', 'show', 'suitable', 'support', 'task', 'thank', 'thanks', 'that', 'there', 'till', 'time', 'to', 'transfer', 'up', 'want', 'what', 'which', 'with', 'you']

# %%
# create our training data
training = []
# create an empty array for our output
output_empty = [0] * len(classes)
# training set, bag of words for each sentence
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)
    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    training.append([bag, output_row])
# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training)
# create train and test lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data created")
# Out:
# Training data created
# C:\Users\John Barry\miniconda3\envs\Chatbot3\lib\site-packages\ipykernel_launcher.py:22: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))
# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
#fitting and saving the model 
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)
print("model created")
# Out:
# Epoch 1/200
# 10/10 [==============================] - 1s 2ms/step - loss: 2.2300 - accuracy: 0.1485
# Epoch 2/200
# 10/10 [==============================] - 0s 2ms/step - loss: 2.1158 - accuracy: 0.3163
# Epoch 3/200
# 10/10 [==============================] - 0s 3ms/step - loss: 2.0718 - accuracy: 0.1491
# Epoch 4/200
# 10/10 [==============================] - 0s 3ms/step - loss: 2.0217 - accuracy: 0.2413
# Epoch 5/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.9093 - accuracy: 0.4204
# Epoch 6/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.8300 - accuracy: 0.3975
# Epoch 7/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.7117 - accuracy: 0.4681
# Epoch 8/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.6256 - accuracy: 0.4709
# Epoch 9/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.3449 - accuracy: 0.7514
# Epoch 10/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.4132 - accuracy: 0.5252
# Epoch 11/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.1787 - accuracy: 0.6633
# Epoch 12/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.0059 - accuracy: 0.7487
# Epoch 13/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.9030 - accuracy: 0.7485
# Epoch 14/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.7946 - accuracy: 0.8586
# Epoch 15/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.8051 - accuracy: 0.8815
# Epoch 16/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.8143 - accuracy: 0.7017
# Epoch 17/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6881 - accuracy: 0.8864
# Epoch 18/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.8471 - accuracy: 0.7109
# Epoch 19/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6220 - accuracy: 0.8938
# Epoch 20/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.5411 - accuracy: 0.9252
# Epoch 21/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5432 - accuracy: 0.8674
# Epoch 22/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3900 - accuracy: 0.8706
# Epoch 23/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3844 - accuracy: 0.9067
# Epoch 24/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4663 - accuracy: 0.8651
# Epoch 25/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3293 - accuracy: 0.8753
# Epoch 26/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3757 - accuracy: 0.9165
# Epoch 27/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2917 - accuracy: 0.9107
# Epoch 28/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2853 - accuracy: 0.8915
# Epoch 29/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2662 - accuracy: 0.8706
# Epoch 30/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2578 - accuracy: 0.9803
# Epoch 31/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1579 - accuracy: 0.9941
# Epoch 32/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3045 - accuracy: 0.9403
# Epoch 33/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2184 - accuracy: 0.9892
# Epoch 34/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2119 - accuracy: 0.9211
# Epoch 35/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1815 - accuracy: 0.9350
# Epoch 36/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2327 - accuracy: 0.9348
# Epoch 37/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1121 - accuracy: 1.0000
# Epoch 38/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2158 - accuracy: 0.9416
# Epoch 39/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1490 - accuracy: 0.9941
# Epoch 40/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2296 - accuracy: 0.9362
# Epoch 41/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1423 - accuracy: 0.9892
# Epoch 42/200
# 10/10 [==============================] - ETA: 0s - loss: 0.3592 - accuracy: 0.80 - 0s 3ms/step - loss: 0.2370 - accuracy: 0.9047
# Epoch 43/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0872 - accuracy: 1.0000
# Epoch 44/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1885 - accuracy: 0.9309
# Epoch 45/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1373 - accuracy: 0.9688
# Epoch 46/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0679 - accuracy: 1.0000
# Epoch 47/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1171 - accuracy: 0.9862
# Epoch 48/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1375 - accuracy: 1.0000
# Epoch 49/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0502 - accuracy: 0.9862
# Epoch 50/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0643 - accuracy: 1.0000
# Epoch 51/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0965 - accuracy: 1.0000
# Epoch 52/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0957 - accuracy: 0.9780
# Epoch 53/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0274 - accuracy: 1.0000
# Epoch 54/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0603 - accuracy: 1.0000
# Epoch 55/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0999 - accuracy: 0.9699
# Epoch 56/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0878 - accuracy: 1.0000
# Epoch 57/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0964 - accuracy: 0.9918
# Epoch 58/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0685 - accuracy: 1.0000
# Epoch 59/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1062 - accuracy: 0.9547
# Epoch 60/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0236 - accuracy: 1.0000
# Epoch 61/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1083 - accuracy: 0.9811
# Epoch 62/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0527 - accuracy: 0.9918
# Epoch 63/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0923 - accuracy: 0.9629
# Epoch 64/200
# 10/10 [==============================] - ETA: 0s - loss: 0.0470 - accuracy: 1.00 - 0s 1ms/step - loss: 0.1321 - accuracy: 0.9348
# Epoch 65/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0734 - accuracy: 0.9892
# Epoch 66/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0698 - accuracy: 1.0000
# Epoch 67/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0251 - accuracy: 0.9882
# Epoch 68/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1315 - accuracy: 0.9629
# Epoch 69/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0460 - accuracy: 0.9941
# Epoch 70/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0335 - accuracy: 1.0000
# Epoch 71/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0459 - accuracy: 0.9720
# Epoch 72/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0637 - accuracy: 1.0000
# Epoch 73/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0710 - accuracy: 0.9673
# Epoch 74/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0487 - accuracy: 0.9629
# Epoch 75/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0748 - accuracy: 0.9720
# Epoch 76/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0843 - accuracy: 0.9301
# Epoch 77/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1416 - accuracy: 0.9638
# Epoch 78/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0667 - accuracy: 0.9720
# Epoch 79/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0417 - accuracy: 1.0000
# Epoch 80/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0213 - accuracy: 1.0000
# Epoch 81/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0330 - accuracy: 1.0000
# Epoch 82/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1013 - accuracy: 1.0000
# Epoch 83/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1170 - accuracy: 0.9629
# Epoch 84/200
# 10/10 [==============================] - 0s 998us/step - loss: 0.0219 - accuracy: 1.0000
# Epoch 85/200
# 10/10 [==============================] - 0s 997us/step - loss: 0.0221 - accuracy: 1.0000
# Epoch 86/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0247 - accuracy: 0.9918
# Epoch 87/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0140 - accuracy: 1.0000
# Epoch 88/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0485 - accuracy: 0.9780
# Epoch 89/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0137 - accuracy: 1.0000
# Epoch 90/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0223 - accuracy: 1.0000
# Epoch 91/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0585 - accuracy: 1.0000
# Epoch 92/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0477 - accuracy: 1.0000
# Epoch 93/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0599 - accuracy: 1.0000
# Epoch 94/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0306 - accuracy: 1.0000
# Epoch 95/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0415 - accuracy: 1.0000
# Epoch 96/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0183 - accuracy: 1.0000
# Epoch 97/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1211 - accuracy: 0.9720
# Epoch 98/200
# 10/10 [==============================] - 0s 997us/step - loss: 0.0166 - accuracy: 1.0000
# Epoch 99/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0355 - accuracy: 1.0000
# Epoch 100/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0422 - accuracy: 1.0000
# Epoch 101/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0349 - accuracy: 1.0000
# Epoch 102/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0199 - accuracy: 1.0000
# Epoch 103/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0472 - accuracy: 1.0000
# Epoch 104/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0093 - accuracy: 1.0000
# Epoch 105/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0785 - accuracy: 0.9720
# Epoch 106/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0249 - accuracy: 1.0000
# Epoch 107/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0353 - accuracy: 0.9780
# Epoch 108/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0677 - accuracy: 0.9892
# Epoch 109/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0292 - accuracy: 1.0000
# Epoch 110/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0228 - accuracy: 1.0000
# Epoch 111/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0183 - accuracy: 1.0000
# Epoch 112/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0099 - accuracy: 0.9961
# Epoch 113/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0323 - accuracy: 1.0000
# Epoch 114/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0580 - accuracy: 0.9720
# Epoch 115/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0209 - accuracy: 0.9941
# Epoch 116/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 117/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0540 - accuracy: 0.9447
# Epoch 118/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0248 - accuracy: 1.0000
# Epoch 119/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0674 - accuracy: 0.9553
# Epoch 120/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0472 - accuracy: 0.9918
# Epoch 121/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0180 - accuracy: 1.0000
# Epoch 122/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0182 - accuracy: 1.0000
# Epoch 123/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0328 - accuracy: 1.0000
# Epoch 124/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0096 - accuracy: 0.9961
# Epoch 125/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0533 - accuracy: 1.0000
# Epoch 126/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0530 - accuracy: 1.0000
# Epoch 127/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0563 - accuracy: 1.0000
# Epoch 128/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0637 - accuracy: 0.9661
# Epoch 129/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0100 - accuracy: 1.0000
# Epoch 130/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0107 - accuracy: 1.0000
# Epoch 131/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0266 - accuracy: 0.9826
# Epoch 132/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1044 - accuracy: 0.9447
# Epoch 133/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0135 - accuracy: 1.0000
# Epoch 134/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0514 - accuracy: 0.9780
# Epoch 135/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0414 - accuracy: 0.9941
# Epoch 136/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0128 - accuracy: 1.0000
# Epoch 137/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0135 - accuracy: 1.0000
# Epoch 138/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0093 - accuracy: 1.0000
# Epoch 139/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0291 - accuracy: 1.0000
# Epoch 140/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 141/200
# 10/10 [==============================] - 0s 886us/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 142/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0143 - accuracy: 1.0000
# Epoch 143/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0206 - accuracy: 1.0000
# Epoch 144/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0176 - accuracy: 1.0000
# Epoch 145/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0079 - accuracy: 1.0000
# Epoch 146/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0110 - accuracy: 1.0000
# Epoch 147/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 148/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0331 - accuracy: 1.0000
# Epoch 149/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0262 - accuracy: 1.0000
# Epoch 150/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 151/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 152/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0258 - accuracy: 0.9862
# Epoch 153/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 154/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 155/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0197 - accuracy: 0.9941
# Epoch 156/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 157/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0436 - accuracy: 1.0000
# Epoch 158/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0086 - accuracy: 1.0000
# Epoch 159/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0726 - accuracy: 0.9491
# Epoch 160/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0061 - accuracy: 1.0000
# Epoch 161/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0111 - accuracy: 1.0000
# Epoch 162/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 163/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0062 - accuracy: 1.0000
# Epoch 164/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0088 - accuracy: 1.0000
# Epoch 165/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 166/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0351 - accuracy: 0.9941
# Epoch 167/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0244 - accuracy: 1.0000
# Epoch 168/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0237 - accuracy: 1.0000
# Epoch 169/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0082 - accuracy: 1.0000
# Epoch 170/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0160 - accuracy: 1.0000
# Epoch 171/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0104 - accuracy: 1.0000
# Epoch 172/200
# 10/10 [==============================] - 0s 997us/step - loss: 0.0143 - accuracy: 0.9918
# Epoch 173/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 174/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 175/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0110 - accuracy: 1.0000
# Epoch 176/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 177/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0240 - accuracy: 0.9826
# Epoch 178/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0162 - accuracy: 1.0000
# Epoch 179/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 180/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0669 - accuracy: 0.9545
# Epoch 181/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0213 - accuracy: 1.0000
# Epoch 182/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0086 - accuracy: 1.0000
# Epoch 183/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0100 - accuracy: 1.0000
# Epoch 184/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0059 - accuracy: 1.0000
# Epoch 185/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0117 - accuracy: 1.0000
# Epoch 186/200
# 10/10 [==============================] - 0s 886us/step - loss: 0.0181 - accuracy: 1.0000
# Epoch 187/200
# 10/10 [==============================] - 0s 885us/step - loss: 0.0109 - accuracy: 1.0000
# Epoch 188/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 189/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0339 - accuracy: 1.0000
# Epoch 190/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 191/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0086 - accuracy: 1.0000
# Epoch 192/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0430 - accuracy: 0.9629
# Epoch 193/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 194/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0192 - accuracy: 1.0000
# Epoch 195/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0491 - accuracy: 0.9720
# Epoch 196/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0059 - accuracy: 1.0000
# Epoch 197/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 198/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0146 - accuracy: 1.0000
# Epoch 199/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0269 - accuracy: 0.9780
# Epoch 200/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0043 - accuracy: 1.0000
# model created

# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import pickle
import numpy as np
from keras.models import load_model
model = load_model('chatbot_model.h5')
import json
import random
intents = json.loads(open('intents.json').read())
words = pickle.load(open('words.pkl','rb'))
classes = pickle.load(open('classes.pkl','rb'))

# %%
def clean_up_sentence(sentence):
    # tokenize the pattern - split words into array
    sentence_words = nltk.word_tokenize(sentence)
    # stem each word - create short form for word
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words
# return bag of words array: 0 or 1 for each word in the bag that exists in the sentence
def bow(sentence, words, show_details=True):
    # tokenize the pattern
    sentence_words = clean_up_sentence(sentence)
    # bag of words - matrix of N words, vocabulary matrix
    bag = [0]*len(words) 
    for s in sentence_words:
        for i,w in enumerate(words):
            if w == s: 
                # assign 1 if current word is in the vocabulary position
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % w)
    return(np.array(bag))
def predict_class(sentence, model):
    # filter out predictions below a threshold
    p = bow(sentence, words,show_details=False)
    res = model.predict(np.array([p]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i,r] for i,r in enumerate(res) if r>ERROR_THRESHOLD]
    # sort by strength of probability
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list

# %%
def getResponse(ints, intents_json):
    tag = ints[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if(i['tag']== tag):
            result = random.choice(i['responses'])
            break
    return result
def chatbot_response(text):
    ints = predict_class(text, model)
    res = getResponse(ints, intents)
    return res

# %%
#Creating GUI with tkinter
import tkinter
from tkinter import *
def send():
    msg = EntryBox.get("1.0",'end-1c').strip()
    EntryBox.delete("0.0",END)
    if msg != '':
        ChatLog.config(state=NORMAL)
        ChatLog.insert(END, "You: " + msg + '\n\n')
        ChatLog.config(foreground="#442265", font=("Verdana", 12 ))
        res = chatbot_response(msg)
        ChatLog.insert(END, "Bot: " + res + '\n\n')
        ChatLog.config(state=DISABLED)
        ChatLog.yview(END)
base = Tk()
base.title("Hello")
base.geometry("400x500")
base.resizable(width=FALSE, height=FALSE)
#Create Chat window
ChatLog = Text(base, bd=0, bg="white", height="8", width="50", font="Arial",)
ChatLog.config(state=DISABLED)
#Bind scrollbar to Chat window
scrollbar = Scrollbar(base, command=ChatLog.yview, cursor="heart")
ChatLog['yscrollcommand'] = scrollbar.set
#Create Button to send message
SendButton = Button(base, font=("Verdana",12,'bold'), text="Send", width="12", height=5,
                    bd=0, bg="#32de97", activebackground="#3c9d9b",fg='#ffffff',
                    command= send )
#Create the box to enter message
EntryBox = Text(base, bd=0, bg="white",width="29", height="5", font="Arial")
#EntryBox.bind("<Return>", send)
#Place all components on the screen
scrollbar.place(x=376,y=6, height=386)
ChatLog.place(x=6,y=6, height=386, width=370)
EntryBox.place(x=128, y=401, height=90, width=265)
SendButton.place(x=6, y=401, height=90)
base.mainloop()
